# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filepath = "pseudolabels_better.csv"

df = pd.read_csv(filepath)
df.head()
# Out:
#                    row_id   1139490   1192948   1194042    126247   1346504  \
# 0   H02_20230420_164000_5  0.002050  0.002291  0.006052  0.006620  0.003949
# 1  H02_20230420_164000_10  0.001539  0.003135  0.003382  0.002715  0.002341
# 2  H02_20230420_164000_15  0.001318  0.001733  0.004384  0.001795  0.002707
# 3  H02_20230420_164000_20  0.001195  0.001340  0.006546  0.003283  0.002959
# 4  H02_20230420_164000_25  0.001086  0.000892  0.003667  0.004538  0.002734
#
#      134933    135045   1462711   1462737  ...   yebfly1   yebsee1   yecspi2  \
# 0  0.002850  0.010011  0.004700  0.013956  ...  0.006785  0.041201  0.007305
# 1  0.002171  0.017677  0.002542  0.011326  ...  0.003652  0.013005  0.006528
# 2  0.003135  0.009621  0.002625  0.015540  ...  0.004603  0.008352  0.008671
# 3  0.003423  0.005741  0.001980  0.020977  ...  0.007339  0.012651  0.007288
# 4  0.004851  0.004254  0.001985  0.015244  ...  0.007694  0.011498  0.007733
#
# ...

# %%
df.sample(n=2, axis="index")
# Out:
#                        row_id   1139490   1192948   1194042    126247  \
# 15912   H09_20230509_131000_5  0.001387  0.001834  0.000982  0.000617
# 54855  H32_20230428_220000_20  0.001874  0.001317  0.003744  0.013344
#
#         1346504    134933    135045   1462711   1462737  ...   yebfly1  \
# 15912  0.000573  0.001431  0.039519  0.003093  0.365767  ...  0.005883
# 54855  0.003339  0.014162  0.008541  0.002917  0.127559  ...  0.003865
#
#         yebsee1   yecspi2   yectyr1   yehbla2   yehcar1   yelori1   yeofly1  \
# 15912  0.003913  0.005075  0.050241  0.000278  0.010237  0.063232  0.007360
# 54855  0.008981  0.011152  0.010696  0.002994  0.020781  0.006381  0.009889
#
#         yercac1    ywcpar
# 15912  0.027822  0.001131
# 54855  0.011441  0.010247
#
# [2 rows x 207 columns]

# %%
plt.figure(figsize=(20, 20))
n=10
for i, (sample, row) in enumerate(df.sample(n, axis="index").iterrows()):
    plt.subplot(n//2, 2, i+1)
    plt.bar(range(206), height=row[1:])
    plt.ylim(0,0.4)
plt.tight_layout()
plt.show()
